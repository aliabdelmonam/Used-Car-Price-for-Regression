# %% [markdown]
# <a href="https://www.kaggle.com/code/aliabdelmenam/used-car-price-regreesion?scriptVersionId=195925375" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/aliabdelmonam/Used-Car-Price-for-Regression/blob/main/Regreesion_for_used_car_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from sklearn.preprocessing import StandardScaler,OrdinalEncoder,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from datetime import date
from sklearn.ensemble import IsolationForest,VotingRegressor

# %%
tr= pd.read_csv('/kaggle/input/playground-series-s4e9/train.csv')
ts= pd.read_csv('/kaggle/input/playground-series-s4e9/test.csv')
# y_zz = pd.read_csv('/kaggle/input/playground-series-s4e9/sample_submission.csv')

# %%
# y_zz.drop('id',axis=1,inplace=True)

# %%
tr.shape
# Out:
# (188533, 13)

# %%
tr.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %%
df_train = copy.deepcopy(tr)
df_test = copy.deepcopy(ts)

# %%
pd.set_option('display.max_columns', None)

# %%
# print(df_train['engine'].iloc[:150].to_string())

# %%
# for col in df_train.select_dtypes(include='object'):
#     print(col)
#     print(df_train[col].nunique())
#     print(df_train[col].unique())
#     print('-----------------------------------------')

# %%
# for col in df_train.select_dtypes(include='object'):
#     print(df_train[col].value_counts().sort_values(ascending=False).head(10))
#     print('----------------------------------------------------')

# %%
df_train.isna().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %% [markdown]
# # **VIS**

# %%
# cols_dict = {
#       'brand':'brand',
#       'model_year':'model_year',
#       "accident": "accident",
#       "exterior color" : "ext_col",
#       "interior color" : "int_col",
# }
# target='price'

# %%
# props1 = "background-color: white; color: maroon; font-weight: bold; "
# props2 = "background-color: white; color: blue; font-weight: bold; "

# %%
# for label, col in cols_dict.items():
#   t=tr[[col,target]].groupby(col).agg({target: ["max", "min", "mean", "median", "size"]})
#   display(t.sort_values(by = col, ascending = True).\
#                 transpose().\
#                 style.format(formatter = '{:,.0f}').\
#                 set_caption(f"\nPrice details by {label}\n").\
#                 highlight_max(axis=1, props = props1).\
#                 highlight_min(axis=1, props = props2)
#                  )
#   print("\n\n\n")

# %%
# pd.options.display.float_format = '{:.5f}'.format

# %%
import re

# %% [markdown]
# # **Feature Extraction**

# %%
df_train['Horse_power']= df_train['engine'].str.extract(r'(\d+)\.?\d*HP').astype(float)
df_train['Engine_Displacement']= df_train['engine'].str.extract(r'(\d+\.?\d*)L').astype(float)
df_train['Cylinder_Count']= df_train['engine'].str.extract(r'(\d+) Cylinder ').astype(float)

df_test['Horse_power']= df_test['engine'].str.extract(r'(\d+)\.?\d*HP').astype(float)
df_test['Engine_Displacement']= df_test['engine'].str.extract(r'(\d+\.?\d*)L').astype(float)
df_test['Cylinder_Count']= df_test['engine'].str.extract(r'(\d+) Cylinder ').astype(float)

cylinder_config={'V','Flat','Straight'}
Turbocharger = {'Turbo','Twin Turbo'}
engine_type ={'Gasoline','Electric','Hybrid'}
FUEL_SYSTEMS = {'MPFI', 'GDI', 'PDI', 'TFSI','DOHC', 'SOHC'}

# %%
def zoo(word,cylinder_config):
  for i in cylinder_config:
    if i in word:
      return i
  return 'Nan'

# %%
df_train['cylinder_config']=df_train['engine'].apply(zoo,args=(cylinder_config,))
df_train['Turbocharger']=df_train['engine'].apply(zoo,args=(Turbocharger,))
df_train['engine_type']=df_train['engine'].apply(zoo,args=(engine_type,))
df_train['FUEL_SYSTEMS']=df_train['engine'].apply(zoo,args=(FUEL_SYSTEMS,))

df_test['cylinder_config']=df_test['engine'].apply(zoo,args=(cylinder_config,))
df_test['Turbocharger']=df_test['engine'].apply(zoo,args=(Turbocharger,))
df_test['engine_type']=df_test['engine'].apply(zoo,args=(engine_type,))
df_test['FUEL_SYSTEMS']=df_test['engine'].apply(zoo,args=(FUEL_SYSTEMS,))

# %%
df_train
# Out:
#             id          brand                     model  model_year  milage  \
# 0            0           MINI             Cooper S Base        2007  213000
# 1            1        Lincoln                     LS V8        2002  143250
# 2            2      Chevrolet         Silverado 2500 LT        2002  136731
# 3            3        Genesis          G90 5.0 Ultimate        2017   19500
# 4            4  Mercedes-Benz               Metris Base        2021    7388
# ...        ...            ...                       ...         ...     ...
# 188528  188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188531  188531           Audi          S5 3.0T Prestige        2022   13895
# 188532  188532        Porsche                Macan Base        2016   59500
#
#             fuel_type                                             engine  \
# 0            Gasoline       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1            Gasoline       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2       E85 Flex Fuel  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3            Gasoline       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4            Gasoline       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...               ...                                                ...
# 188528       Gasoline       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188529       Gasoline      385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188530       Gasoline       469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188531       Gasoline                                               3.0L
# 188532       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                           transmission                    ext_col int_col  \
# 0                                  A/T                     Yellow    Gray
# 1                                  A/T                     Silver   Beige
# 2                                  A/T                       Blue    Gray
# 3       Transmission w/Dual Shift Mode                      Black   Black
# 4                          7-Speed A/T                      Black   Beige
# ...                                ...                        ...     ...
# 188528  Transmission w/Dual Shift Mode                      White   Beige
# 188529                     8-Speed A/T                      White   Black
# 188530                     7-Speed A/T                      White   Black
# 188531               1-Speed Automatic  Daytona Gray Pearl Effect   Black
# 188532  Transmission w/Dual Shift Mode                      White   Black
#
#                                       accident clean_title  price  \
# 0                                None reported         Yes   4200
# 1       At least 1 accident or damage reported         Yes   4999
# 2                                None reported         Yes  13900
# 3                                None reported         Yes  45000
# 4                                None reported         Yes  97500
# ...                                        ...         ...    ...
# 188528                           None reported         Yes  27500
# 188529  At least 1 accident or damage reported         Yes  30000
# 188530                           None reported         Yes  86900
# 188531                           None reported         NaN  84900
# 188532                           None reported         Yes  28995
#
#         Horse_power  Engine_Displacement  Cylinder_Count cylinder_config  \
# 0             172.0                  1.6             4.0             Nan
# 1             252.0                  3.9             8.0             Nan
# 2             320.0                  5.3             8.0             Nan
# 3             420.0                  5.0             8.0             Nan
# 4             208.0                  2.0             4.0             Nan
# ...             ...                  ...             ...             ...
# 188528        420.0                  6.2             8.0             Nan
# 188529        385.0                  3.0             6.0               V
# 188530        469.0                  4.0             8.0             Nan
# 188531          NaN                  3.0             NaN             Nan
# 188532        252.0                  2.0             4.0             Nan
#
#        Turbocharger engine_type FUEL_SYSTEMS
# 0               Nan    Gasoline          Nan
# 1               Nan    Gasoline          Nan
# 2               Nan         Nan          Nan
# 3               Nan    Gasoline          Nan
# 4               Nan    Gasoline          Nan
# ...             ...         ...          ...
# 188528          Nan    Gasoline          Nan
# 188529          Nan    Gasoline          Nan
# 188530          Nan    Gasoline          Nan
# 188531          Nan         Nan          Nan
# 188532          Nan    Gasoline          Nan
#
# [188533 rows x 20 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   188533 non-null  int64
#  1   brand                188533 non-null  object
#  2   model                188533 non-null  object
#  3   model_year           188533 non-null  int64
#  4   milage               188533 non-null  int64
#  5   fuel_type            183450 non-null  object
#  6   engine               188533 non-null  object
#  7   transmission         188533 non-null  object
#  8   ext_col              188533 non-null  object
#  9   int_col              188533 non-null  object
#  10  accident             186081 non-null  object
#  11  clean_title          167114 non-null  object
#  12  price                188533 non-null  int64
#  13  Horse_power          155274 non-null  float64
#  14  Engine_Displacement  174319 non-null  float64
#  15  Cylinder_Count       150625 non-null  float64
#  16  cylinder_config      188533 non-null  object
#  17  Turbocharger         188533 non-null  object
#  18  engine_type          188533 non-null  object
#  19  FUEL_SYSTEMS         188533 non-null  object
# dtypes: float64(3), int64(4), object(13)
# memory usage: 28.8+ MB

# %%
df_train['transmission'].unique()
# Out:
# array(['A/T', 'Transmission w/Dual Shift Mode', '7-Speed A/T',
#        '8-Speed A/T', '10-Speed Automatic', '1-Speed A/T', '6-Speed A/T',
#        '10-Speed A/T', '9-Speed A/T', '8-Speed Automatic',
#        '9-Speed Automatic', '5-Speed A/T', 'Automatic',
#        '7-Speed Automatic with Auto-Shift', 'CVT Transmission',
#        '5-Speed M/T', 'M/T', '6-Speed M/T', '6-Speed Automatic',
#        '4-Speed Automatic', '7-Speed M/T', '2-Speed A/T',
#        '1-Speed Automatic', 'Automatic CVT', '4-Speed A/T',
#        '6-Speed Manual', 'Transmission Overdrive Switch',
#        '8-Speed Automatic with Auto-Shift', '7-Speed Manual',
#        '7-Speed Automatic', '9-Speed Automatic with Auto-Shift',
#        '6-Speed Automatic with Auto-Shift',
#        '6-Speed Electronically Controlled Automatic with O', 'F', 'CVT-F',
#        '8-Speed Manual', 'Manual', '–', '2', '6 Speed At/Mt',
#        '5-Speed Automatic', '2-Speed Automatic', '8-SPEED A/T', '7-Speed',
#        'Variable', 'Single-Speed Fixed Gear', '8-SPEED AT',
#        '10-Speed Automatic with Overdrive', '7-Speed DCT Automatic',
#        'SCHEDULED FOR OR IN PRODUCTION', '6-Speed', '6 Speed Mt'],
#       dtype=object)

# %%
# print(df_train['transmission'].iloc[:150].to_string())

# %%
# df_train['transmission'].value_counts()

# %%
# def extract_transmition (word):
#   def get_number ():
#     n=re.findall('\d+',word)
#     return n[0] if n else ''
#   if any(i in word for i in ['AT','A/T','At/Mt','Automatic'] ):
#     return ('AT'+str(get_number()))
#   elif any(i in word for i in ['CVT'] ):
#      return ('CVT'+str(get_number()))
#   elif any(i in word for i in ['Manual','M/T'] ):
#     return ('MT'+str(get_number()))
#   else :
#     return 'other'
def extract_transmition (word):
  def get_number ():
    n=re.findall('\d+',word)
    return n[0] if n else ''
  if any(i in word for i in ['AT','A/T','At/Mt','Automatic'] ):
    return ('AT')
  elif any(i in word for i in ['CVT'] ):
     return ('CVT')
  elif any(i in word for i in ['Manual','M/T'] ):
    return ('MT')
  else :
    return 'other'

# %%
df_train['new_transmission']=df_train['transmission'].apply(extract_transmition)
df_test['new_transmission']=df_test['transmission'].apply(extract_transmition)

# %%
df_train[['new_transmission','transmission']].head(20)
# Out:
#    new_transmission                    transmission
# 0                AT                             A/T
# 1                AT                             A/T
# 2                AT                             A/T
# 3             other  Transmission w/Dual Shift Mode
# 4                AT                     7-Speed A/T
# 5                AT                             A/T
# 6                AT                     8-Speed A/T
# 7                AT                             A/T
# 8                AT              10-Speed Automatic
# 9             other  Transmission w/Dual Shift Mode
# 10               AT                             A/T
# 11               AT                     1-Speed A/T
# 12               AT                     6-Speed A/T
# 13               AT                             A/T
# 14               AT                             A/T
# 15               AT                     7-Speed A/T
# 16               AT                    10-Speed A/T
# 17               AT                     8-Speed A/T
# 18               AT                     7-Speed A/T
# 19               AT                     9-Speed A/T

# %%
year = date.today().year
df_train['model_age'] = year - df_train['model_year']
df_test['model_age'] = year - df_test['model_year']

# %%
df_train.drop(['engine','transmission'],axis=1,inplace=True)
df_test.drop(['engine','transmission'],axis=1,inplace=True)
df_train.drop('id',axis=1,inplace=True)
df_test.drop('id',axis=1,inplace=True)
df_train.drop(['model_year'],axis=1,inplace=True)
df_test.drop(['model_year'],axis=1,inplace=True)

# %%
df_test.head()
# Out:
#   brand                 model  milage fuel_type          ext_col int_col  \
# 0  Land        Rover LR2 Base   98000  Gasoline            White   Beige
# 1  Land     Rover Defender SE    9142    Hybrid           Silver   Black
# 2  Ford    Expedition Limited   28121  Gasoline            White   Ebony
# 3  Audi         A6 2.0T Sport   61258  Gasoline  Silician Yellow   Black
# 4  Audi  A6 2.0T Premium Plus   59000  Gasoline             Gray   Black
#
#         accident clean_title  Horse_power  Engine_Displacement  \
# 0  None reported         Yes        240.0                  2.0
# 1  None reported         Yes        395.0                  3.0
# 2  None reported         NaN          NaN                  3.5
# 3  None reported         NaN          NaN                  NaN
# 4  None reported         Yes        252.0                  2.0
#
#    Cylinder_Count cylinder_config Turbocharger engine_type FUEL_SYSTEMS  \
# 0             4.0             Nan          Nan    Gasoline          Nan
# 1             6.0        Straight          Nan    Electric          Nan
# 2             NaN               V   Twin Turbo         Nan         DOHC
# 3             NaN             Nan          Nan         Nan         TFSI
# 4             4.0             Nan          Nan    Gasoline          Nan
#
#   new_transmission  model_age
# 0               AT          9
# 1               AT          4
# 2               AT          2
# 3               AT          8
# 4               AT          6

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   brand                188533 non-null  object
#  1   model                188533 non-null  object
#  2   milage               188533 non-null  int64
#  3   fuel_type            183450 non-null  object
#  4   ext_col              188533 non-null  object
#  5   int_col              188533 non-null  object
#  6   accident             186081 non-null  object
#  7   clean_title          167114 non-null  object
#  8   price                188533 non-null  int64
#  9   Horse_power          155274 non-null  float64
#  10  Engine_Displacement  174319 non-null  float64
#  11  Cylinder_Count       150625 non-null  float64
#  12  cylinder_config      188533 non-null  object
#  13  Turbocharger         188533 non-null  object
#  14  engine_type          188533 non-null  object
#  15  FUEL_SYSTEMS         188533 non-null  object
#  16  new_transmission     188533 non-null  object
#  17  model_age            188533 non-null  int64
# dtypes: float64(3), int64(3), object(12)
# memory usage: 25.9+ MB

# %%
df_train.isna().sum()
# Out:
# brand                      0
# model                      0
# milage                     0
# fuel_type               5083
# ext_col                    0
# int_col                    0
# accident                2452
# clean_title            21419
# price                      0
# Horse_power            33259
# Engine_Displacement    14214
# Cylinder_Count         37908
# cylinder_config            0
# Turbocharger               0
# engine_type                0
# FUEL_SYSTEMS               0
# new_transmission           0
# model_age                  0
# dtype: int64

# %%
df_train.head()
# Out:
#            brand              model  milage      fuel_type ext_col int_col  \
# 0           MINI      Cooper S Base  213000       Gasoline  Yellow    Gray
# 1        Lincoln              LS V8  143250       Gasoline  Silver   Beige
# 2      Chevrolet  Silverado 2500 LT  136731  E85 Flex Fuel    Blue    Gray
# 3        Genesis   G90 5.0 Ultimate   19500       Gasoline   Black   Black
# 4  Mercedes-Benz        Metris Base    7388       Gasoline   Black   Beige
#
#                                  accident clean_title  price  Horse_power  \
# 0                           None reported         Yes   4200        172.0
# 1  At least 1 accident or damage reported         Yes   4999        252.0
# 2                           None reported         Yes  13900        320.0
# 3                           None reported         Yes  45000        420.0
# 4                           None reported         Yes  97500        208.0
#
#    Engine_Displacement  Cylinder_Count cylinder_config Turbocharger  \
# 0                  1.6             4.0             Nan          Nan
# 1                  3.9             8.0             Nan          Nan
# 2                  5.3             8.0             Nan          Nan
# 3                  5.0             8.0             Nan          Nan
# 4                  2.0             4.0             Nan          Nan
#
#   engine_type FUEL_SYSTEMS new_transmission  model_age
# 0    Gasoline          Nan               AT         17
# 1    Gasoline          Nan               AT         22
# 2         Nan          Nan               AT         22
# 3    Gasoline          Nan            other          7
# 4    Gasoline          Nan               AT          3

# %%
y=df_train['price']
df_train=df_train.drop('price',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(df_train,y,test_size=.2,random_state=42)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   brand                188533 non-null  object
#  1   model                188533 non-null  object
#  2   milage               188533 non-null  int64
#  3   fuel_type            183450 non-null  object
#  4   ext_col              188533 non-null  object
#  5   int_col              188533 non-null  object
#  6   accident             186081 non-null  object
#  7   clean_title          167114 non-null  object
#  8   Horse_power          155274 non-null  float64
#  9   Engine_Displacement  174319 non-null  float64
#  10  Cylinder_Count       150625 non-null  float64
#  11  cylinder_config      188533 non-null  object
#  12  Turbocharger         188533 non-null  object
#  13  engine_type          188533 non-null  object
#  14  FUEL_SYSTEMS         188533 non-null  object
#  15  new_transmission     188533 non-null  object
#  16  model_age            188533 non-null  int64
# dtypes: float64(3), int64(2), object(12)
# memory usage: 24.5+ MB

# %% [markdown]
# # **PipeLine**

# %%
num_col = df_train.select_dtypes(include='number').columns
cat_col = df_train.select_dtypes(include='object').columns

# %%
num_imputer= SimpleImputer(strategy='mean')
cat_imputer= SimpleImputer(strategy='most_frequent')
encoder = OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value=-1)
scaler = StandardScaler()
#############################################3
for col in num_col:
  x_train[col] = num_imputer.fit_transform(x_train[[col]])
  x_test[col] = num_imputer.transform(x_test[[col]])

  df_test[col] = num_imputer.transform(df_test[[col]])

  x_train[col] = scaler.fit_transform(x_train[[col]])
  x_test[col] = scaler.transform(x_test[[col]])
  df_test[col] = scaler.transform(df_test[[col]])
##############################################
for col in cat_col:
  x_train[[col]] = cat_imputer.fit_transform(x_train[col].values.reshape(-1,1))
  x_test[[col]] = cat_imputer.transform(x_test[col].values.reshape(-1,1))

  df_test[[col]] = cat_imputer.transform(df_test[col].values.reshape(-1,1))

  x_train[col] = encoder.fit_transform(x_train[[col]])
  x_test[col] = encoder.transform(x_test[[col]])

  df_test[col] = encoder.transform(df_test[[col]])

# %%
df_train.head()
# Out:
#            brand              model  milage      fuel_type ext_col int_col  \
# 0           MINI      Cooper S Base  213000       Gasoline  Yellow    Gray
# 1        Lincoln              LS V8  143250       Gasoline  Silver   Beige
# 2      Chevrolet  Silverado 2500 LT  136731  E85 Flex Fuel    Blue    Gray
# 3        Genesis   G90 5.0 Ultimate   19500       Gasoline   Black   Black
# 4  Mercedes-Benz        Metris Base    7388       Gasoline   Black   Beige
#
#                                  accident clean_title  Horse_power  \
# 0                           None reported         Yes        172.0
# 1  At least 1 accident or damage reported         Yes        252.0
# 2                           None reported         Yes        320.0
# 3                           None reported         Yes        420.0
# 4                           None reported         Yes        208.0
#
#    Engine_Displacement  Cylinder_Count cylinder_config Turbocharger  \
# 0                  1.6             4.0             Nan          Nan
# 1                  3.9             8.0             Nan          Nan
# 2                  5.3             8.0             Nan          Nan
# 3                  5.0             8.0             Nan          Nan
# 4                  2.0             4.0             Nan          Nan
#
#   engine_type FUEL_SYSTEMS new_transmission  model_age
# 0    Gasoline          Nan               AT         17
# 1    Gasoline          Nan               AT         22
# 2         Nan          Nan               AT         22
# 3    Gasoline          Nan            other          7
# 4    Gasoline          Nan               AT          3

# %%
pd.options.display.float_format = '{:.3f}'.format

# %%
zob=pd.DataFrame(x_train,columns=df_train.columns)
zob
# Out:
#         brand   model  milage  fuel_type  ext_col  int_col  accident  \
# 184031 36.000 764.000  -0.082      1.000  128.000   14.000     0.000
# 173831 39.000 732.000   2.396      2.000  263.000   71.000     0.000
# 183819 14.000 670.000   0.527      2.000  128.000   71.000     0.000
# 85525  19.000 583.000  -1.211      2.000   29.000   14.000     1.000
# 41872  11.000 457.000  -1.221      2.000  234.000   14.000     1.000
# ...       ...     ...     ...        ...      ...      ...       ...
# 119879  9.000 505.000   0.469      2.000  234.000   10.000     0.000
# 103694  4.000 126.000  -0.170      2.000   29.000   14.000     1.000
# 131932 43.000 147.000  -0.688      2.000   29.000   14.000     1.000
# 146867 36.000 962.000   2.416      2.000   29.000   14.000     1.000
# 121958 32.000 994.000  -1.201      2.000  177.000   14.000     1.000
#
#         clean_title  Horse_power  Engine_Displacement  Cylinder_Count  \
# 184031        0.000       -1.297               -1.386          -1.706
# 173831        0.000       -1.000                0.149          -0.268
# 183819        0.000       -0.175               -0.849          -0.268
# 85525         0.000       -0.645               -1.386          -1.706
# 41872         0.000        3.584                1.838           1.169
# ...             ...          ...                  ...             ...
# 119879        0.000        0.065                1.454           1.169
# 103694        0.000       -0.223               -0.619          -0.268
# 131932        0.000        0.736               -0.619          -0.268
# 146867        0.000       -0.722               -0.235          -0.268
# 121958        0.000       -0.000               -0.619          -0.000
#
#         cylinder_config  Turbocharger  engine_type  FUEL_SYSTEMS  \
# 184031            1.000         0.000        3.000         3.000
# 173831            3.000         0.000        1.000         3.000
# 183819            3.000         0.000        1.000         3.000
# 85525             1.000         0.000        1.000         3.000
# 41872             1.000         0.000        1.000         3.000
# ...                 ...           ...          ...           ...
# 119879            1.000         0.000        1.000         3.000
# 103694            2.000         0.000        1.000         3.000
# 131932            0.000         0.000        1.000         3.000
# 146867            3.000         0.000        1.000         3.000
# 121958            3.000         2.000        3.000         0.000
#
#         new_transmission  model_age
# 184031             3.000     -0.208
# 173831             0.000      2.268
# 183819             0.000     -0.738
# 85525              2.000     -1.268
# 41872              0.000     -1.268
# ...                  ...        ...
# 119879             2.000      1.560
# 103694             0.000     -0.561
# 131932             0.000     -0.915
# 146867             0.000      0.853
# 121958             0.000     -1.268
#
# [150826 rows x 17 columns]

# %% [markdown]
# # **Removing Outliers**

# %%
isolation_forest = IsolationForest(contamination=0.024, random_state=42)
x_train_labels = isolation_forest.fit_predict(x_train) # 1 indicate normal, -1--> outlier (anomaly)
normal_bool = x_train_labels != -1 
x_train=x_train[normal_bool]
y_train=y_train[normal_bool]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(

# %%
# !pip install dython
from dython.nominal import associations
# Out:
# Collecting dython
#   Downloading dython-0.7.7-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from dython) (1.26.4)
# Requirement already satisfied: pandas>=1.4.2 in /opt/conda/lib/python3.10/site-packages (from dython) (2.2.2)
# Requirement already satisfied: seaborn>=0.12.0 in /opt/conda/lib/python3.10/site-packages (from dython) (0.12.2)
# Requirement already satisfied: scipy>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from dython) (1.14.0)
# Requirement already satisfied: matplotlib>=3.6.0 in /opt/conda/lib/python3.10/site-packages (from dython) (3.7.5)
# Requirement already satisfied: scikit-learn>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from dython) (1.2.2)
# Requirement already satisfied: psutil>=5.9.1 in /opt/conda/lib/python3.10/site-packages (from dython) (5.9.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from dython) (70.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->dython) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->dython) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->dython) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->dython) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->dython) (1.16.0)
# Downloading dython-0.7.7-py3-none-any.whl (26 kB)
# Installing collected packages: dython
# Successfully installed dython-0.7.7

# %%
temp  = x_train.merge(y_train,left_index=True,right_index=True)
plt.figure(figsize=(15,10))
df_co=temp.corr()
mask = np.triu(np.ones_like(temp.corr())) 
sns.heatmap(df_co,annot=True,cmap='Blues',fmt='.3f',mask=mask)
plt.show()
# fig, ax = plt.subplots(figsize=(15, 10))
# correlations = associations(tr,ax=ax,cmap='Blues')

# %%
# x_train.drop('brand',axis=1,inplace=True)
# x_test.drop('brand',axis=1,inplace=True)
# df_test.drop('brand',axis=1,inplace=True)

# %%
(1-len(x_train)/len(x_train_labels))*100
# Out:
# 2.3994536750958084

# %%
import xgboost as xgb
from lightgbm import LGBMRegressor
import lightgbm as lgb

# %%
xgb_model=xgb.XGBRegressor(tree_method ="hist",
                              device               = "cuda" ,
                          objective             = "reg:squarederror",
                          random_state          = 42,
                          colsample_bytree      = 0.45,
                          learning_rate       = 0.025,
                          max_depth          = 7,
                          n_estimators          = 700,
                          reg_alpha          = 0.001,
                            reg_lambda            = 0.001,
                            min_child_weight      = 18,
                        enable_categorical    = True,      
                           
                        eval_metric='rmse'  ,
                        early_stopping_rounds=10,
                        verbose = -1
)
lgb_params= {
      'num_leaves': 426,
     'max_depth': 20,
     'learning_rate': 0.011353178352988012,
     'n_estimators': 884,
     'subsample': 0.5772552201954328,
     'colsample_bytree': 0.9164865430101521,
     'reg_alpha': 1.48699088003429e-06,
     'reg_lambda': 0.41539458543414265,
     'min_data_in_leaf': 73,
     'feature_fraction': 0.751673655170548,
     'bagging_fraction': 0.5120415391590843,
     'bagging_freq': 2,
     'min_child_weight': 0.017236362383443497,
     'cat_smooth': 54.81317407769262,
        'verbose':-1
}

# %%
lgb_reg = LGBMRegressor(**lgb_params,loss_function='RMSE',verbosity=-1)
early_stopping_light = lgb.early_stopping(stopping_rounds=10)
eval_Set = [(x_train,y_train),(x_test,y_test)]
lgb_reg.fit(x_train,y_train,eval_set =eval_Set,callbacks=[early_stopping_light],eval_metric='rmse')
xgb_model.fit(x_train,y_train,eval_set=eval_Set)
# Out:
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [294]	training's rmse: 71224.9	training's l2: 5.07298e+09	valid_1's rmse: 67872.6	valid_1's l2: 4.60669e+09
# [0]	validation_0-rmse:79063.26334	validation_1-rmse:74386.14346
# [1]	validation_0-rmse:78885.04270	validation_1-rmse:74193.70567
# [2]	validation_0-rmse:78705.60352	validation_1-rmse:73993.73643
# [3]	validation_0-rmse:78465.34847	validation_1-rmse:73739.06592
# [4]	validation_0-rmse:78240.01641	validation_1-rmse:73511.20150
# [5]	validation_0-rmse:78155.32125	validation_1-rmse:73412.36020
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [11:53:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [6]	validation_0-rmse:77980.40486	validation_1-rmse:73230.21932
# [7]	validation_0-rmse:77834.68169	validation_1-rmse:73069.42804
# [8]	validation_0-rmse:77681.24344	validation_1-rmse:72908.57389
# [9]	validation_0-rmse:77531.38686	validation_1-rmse:72755.85667
# [10]	validation_0-rmse:77352.35180	validation_1-rmse:72573.27277
# [11]	validation_0-rmse:77171.11068	validation_1-rmse:72381.48999
# [12]	validation_0-rmse:77040.81034	validation_1-rmse:72242.57106
# [13]	validation_0-rmse:76928.85691	validation_1-rmse:72129.54459
# [14]	validation_0-rmse:76768.16648	validation_1-rmse:71961.99683
# [15]	validation_0-rmse:76655.76272	validation_1-rmse:71844.27976
# [16]	validation_0-rmse:76586.61279	validation_1-rmse:71761.22247
# [17]	validation_0-rmse:76465.01071	validation_1-rmse:71635.71086
# [18]	validation_0-rmse:76323.96185	validation_1-rmse:71494.38003
# [19]	validation_0-rmse:76178.10895	validation_1-rmse:71341.31045
# [20]	validation_0-rmse:76079.69901	validation_1-rmse:71234.63040
# [21]	validation_0-rmse:75992.51306	validation_1-rmse:71138.67176
# [22]	validation_0-rmse:75925.91066	validation_1-rmse:71070.45845
# [23]	validation_0-rmse:75808.21504	validation_1-rmse:70958.18066
# [24]	validation_0-rmse:75681.40810	validation_1-rmse:70834.03488
# [25]	validation_0-rmse:75563.04875	validation_1-rmse:70708.78155
# [26]	validation_0-rmse:75442.87004	validation_1-rmse:70588.56947
# [27]	validation_0-rmse:75375.95357	validation_1-rmse:70517.73890
# [28]	validation_0-rmse:75276.78099	validation_1-rmse:70419.55144
# [29]	validation_0-rmse:75171.86272	validation_1-rmse:70320.88627
# [30]	validation_0-rmse:75073.72122	validation_1-rmse:70230.24417
# [31]	validation_0-rmse:74983.67462	validation_1-rmse:70147.03671
# [32]	validation_0-rmse:74903.74222	validation_1-rmse:70065.52178
# [33]	validation_0-rmse:74852.42595	validation_1-rmse:70014.27929
# [34]	validation_0-rmse:74811.70969	validation_1-rmse:69972.36517
# [35]	validation_0-rmse:74724.78797	validation_1-rmse:69884.55566
# [36]	validation_0-rmse:74658.18149	validation_1-rmse:69818.74978
# [37]	validation_0-rmse:74592.44666	validation_1-rmse:69749.92177
# [38]	validation_0-rmse:74564.30244	validation_1-rmse:69722.18709
# [39]	validation_0-rmse:74488.93237	validation_1-rmse:69658.56834
# [40]	validation_0-rmse:74421.97708	validation_1-rmse:69593.75973
# [41]	validation_0-rmse:74357.54298	validation_1-rmse:69539.19958
# [42]	validation_0-rmse:74293.19034	validation_1-rmse:69481.44670
# [43]	validation_0-rmse:74228.50934	validation_1-rmse:69421.92310
# [44]	validation_0-rmse:74171.15992	validation_1-rmse:69371.26784
# [45]	validation_0-rmse:74115.72395	validation_1-rmse:69319.63541
# [46]	validation_0-rmse:74061.47512	validation_1-rmse:69268.79242
# [47]	validation_0-rmse:73998.43810	validation_1-rmse:69208.29136
# [48]	validation_0-rmse:73977.79467	validation_1-rmse:69186.03338
# [49]	validation_0-rmse:73935.79011	validation_1-rmse:69150.04966
# [50]	validation_0-rmse:73909.47489	validation_1-rmse:69125.90991
# [51]	validation_0-rmse:73852.74574	validation_1-rmse:69085.01948
# [52]	validation_0-rmse:73822.23594	validation_1-rmse:69050.99454
# [53]	validation_0-rmse:73782.86050	validation_1-rmse:69019.33469
# [54]	validation_0-rmse:73737.36118	validation_1-rmse:68980.27860
# [55]	validation_0-rmse:73689.31342	validation_1-rmse:68941.73064
# [56]	validation_0-rmse:73657.05571	validation_1-rmse:68914.88349
# [57]	validation_0-rmse:73604.92673	validation_1-rmse:68869.63916
# [58]	validation_0-rmse:73556.10052	validation_1-rmse:68832.33148
# [59]	validation_0-rmse:73533.73850	validation_1-rmse:68812.24738
# [60]	validation_0-rmse:73507.26168	validation_1-rmse:68788.38186
# [61]	validation_0-rmse:73453.35001	validation_1-rmse:68753.49374
# [62]	validation_0-rmse:73411.62866	validation_1-rmse:68722.68434
# [63]	validation_0-rmse:73383.89262	validation_1-rmse:68697.07304
# [64]	validation_0-rmse:73345.32091	validation_1-rmse:68668.73726
# [65]	validation_0-rmse:73328.03569	validation_1-rmse:68647.32346
# [66]	validation_0-rmse:73301.84662	validation_1-rmse:68626.61167
# [67]	validation_0-rmse:73278.71707	validation_1-rmse:68609.60181
# [68]	validation_0-rmse:73231.40350	validation_1-rmse:68579.74785
# [69]	validation_0-rmse:73208.68481	validation_1-rmse:68556.80184
# [70]	validation_0-rmse:73188.73075	validation_1-rmse:68537.99189
# [71]	validation_0-rmse:73145.36098	validation_1-rmse:68509.90190
# [72]	validation_0-rmse:73135.28172	validation_1-rmse:68502.03641
# [73]	validation_0-rmse:73094.26335	validation_1-rmse:68482.61488
# [74]	validation_0-rmse:73058.18928	validation_1-rmse:68457.97325
# [75]	validation_0-rmse:73019.22918	validation_1-rmse:68438.09882
# [76]	validation_0-rmse:73003.22647	validation_1-rmse:68421.07501
# [77]	validation_0-rmse:72986.47592	validation_1-rmse:68407.95148
# [78]	validation_0-rmse:72952.71091	validation_1-rmse:68384.84675
# [79]	validation_0-rmse:72936.47700	validation_1-rmse:68372.18172
# [80]	validation_0-rmse:72907.59296	validation_1-rmse:68351.71065
# [81]	validation_0-rmse:72878.89800	validation_1-rmse:68328.43433
# [82]	validation_0-rmse:72856.57733	validation_1-rmse:68318.66499
# [83]	validation_0-rmse:72839.66409	validation_1-rmse:68309.79016
# [84]	validation_0-rmse:72825.75386	validation_1-rmse:68301.49798
# [85]	validation_0-rmse:72794.90436	validation_1-rmse:68287.63677
# [86]	validation_0-rmse:72767.40677	validation_1-rmse:68272.31638
# [87]	validation_0-rmse:72754.08883	validation_1-rmse:68263.01104
# [88]	validation_0-rmse:72740.92198	validation_1-rmse:68252.20372
# [89]	validation_0-rmse:72725.62163	validation_1-rmse:68239.52663
# [90]	validation_0-rmse:72697.46037	validation_1-rmse:68226.12359
# [91]	validation_0-rmse:72669.91647	validation_1-rmse:68213.86837
# [92]	validation_0-rmse:72647.62409	validation_1-rmse:68202.53741
# [93]	validation_0-rmse:72609.94712	validation_1-rmse:68186.04462
# [94]	validation_0-rmse:72593.93834	validation_1-rmse:68170.49092
# [95]	validation_0-rmse:72567.64034	validation_1-rmse:68157.50238
# [96]	validation_0-rmse:72559.06548	validation_1-rmse:68149.30085
# [97]	validation_0-rmse:72541.44446	validation_1-rmse:68138.03571
# [98]	validation_0-rmse:72528.35053	validation_1-rmse:68127.07810
# [99]	validation_0-rmse:72518.92495	validation_1-rmse:68122.06616
# [100]	validation_0-rmse:72489.03384	validation_1-rmse:68109.16516
# [101]	validation_0-rmse:72481.93530	validation_1-rmse:68105.97466
# [102]	validation_0-rmse:72476.26831	validation_1-rmse:68103.12532
# [103]	validation_0-rmse:72463.49849	validation_1-rmse:68092.74761
# [104]	validation_0-rmse:72447.15009	validation_1-rmse:68085.04895
# [105]	validation_0-rmse:72429.65019	validation_1-rmse:68075.56132
# [106]	validation_0-rmse:72402.30756	validation_1-rmse:68062.36581
# [107]	validation_0-rmse:72391.86310	validation_1-rmse:68057.83013
# [108]	validation_0-rmse:72383.68886	validation_1-rmse:68054.06833
# [109]	validation_0-rmse:72372.30785	validation_1-rmse:68048.84824
# [110]	validation_0-rmse:72364.00478	validation_1-rmse:68043.48557
# [111]	validation_0-rmse:72347.84831	validation_1-rmse:68036.26001
# [112]	validation_0-rmse:72332.69253	validation_1-rmse:68028.96845
# [113]	validation_0-rmse:72311.43423	validation_1-rmse:68023.52469
# [114]	validation_0-rmse:72299.40756	validation_1-rmse:68013.92124
# [115]	validation_0-rmse:72293.10670	validation_1-rmse:68010.28340
# [116]	validation_0-rmse:72280.34457	validation_1-rmse:68004.57064
# [117]	validation_0-rmse:72268.26948	validation_1-rmse:67998.56853
# [118]	validation_0-rmse:72258.56969	validation_1-rmse:67991.85183
# [119]	validation_0-rmse:72250.24639	validation_1-rmse:67987.96880
# [120]	validation_0-rmse:72231.72995	validation_1-rmse:67979.72830
# [121]	validation_0-rmse:72222.93217	validation_1-rmse:67975.69348
# [122]	validation_0-rmse:72212.20407	validation_1-rmse:67972.21771
# [123]	validation_0-rmse:72201.19868	validation_1-rmse:67968.99754
# [124]	validation_0-rmse:72175.70497	validation_1-rmse:67964.59046
# [125]	validation_0-rmse:72163.24165	validation_1-rmse:67961.53632
# [126]	validation_0-rmse:72152.35103	validation_1-rmse:67958.31821
# [127]	validation_0-rmse:72134.24008	validation_1-rmse:67954.32860
# [128]	validation_0-rmse:72125.64120	validation_1-rmse:67953.61575
# [129]	validation_0-rmse:72109.52580	validation_1-rmse:67952.26477
# [130]	validation_0-rmse:72098.97338	validation_1-rmse:67945.11345
# [131]	validation_0-rmse:72088.86204	validation_1-rmse:67938.62923
# [132]	validation_0-rmse:72084.60276	validation_1-rmse:67937.06030
# [133]	validation_0-rmse:72076.93783	validation_1-rmse:67931.44498
# [134]	validation_0-rmse:72066.14420	validation_1-rmse:67926.45556
# [135]	validation_0-rmse:72054.99794	validation_1-rmse:67923.89659
# [136]	validation_0-rmse:72038.86435	validation_1-rmse:67921.43261
# [137]	validation_0-rmse:72020.45939	validation_1-rmse:67918.57574
# [138]	validation_0-rmse:72012.88240	validation_1-rmse:67916.35781
# [139]	validation_0-rmse:71993.55647	validation_1-rmse:67912.74426
# [140]	validation_0-rmse:71981.82343	validation_1-rmse:67909.80207
# [141]	validation_0-rmse:71961.35859	validation_1-rmse:67911.11411
# [142]	validation_0-rmse:71939.95075	validation_1-rmse:67910.77129
# [143]	validation_0-rmse:71926.96872	validation_1-rmse:67908.86599
# [144]	validation_0-rmse:71911.74255	validation_1-rmse:67905.42338
# [145]	validation_0-rmse:71897.59407	validation_1-rmse:67904.91327
# [146]	validation_0-rmse:71884.87161	validation_1-rmse:67904.76028
# [147]	validation_0-rmse:71871.35961	validation_1-rmse:67902.10731
# [148]	validation_0-rmse:71849.23520	validation_1-rmse:67901.27726
# [149]	validation_0-rmse:71837.58801	validation_1-rmse:67899.98655
# [150]	validation_0-rmse:71820.38106	validation_1-rmse:67896.23797
# [151]	validation_0-rmse:71806.10875	validation_1-rmse:67898.66164
# [152]	validation_0-rmse:71796.39634	validation_1-rmse:67894.11467
# [153]	validation_0-rmse:71783.55480	validation_1-rmse:67892.71247
# [154]	validation_0-rmse:71779.63833	validation_1-rmse:67892.96620
# [155]	validation_0-rmse:71762.89757	validation_1-rmse:67893.14495
# [156]	validation_0-rmse:71755.40601	validation_1-rmse:67894.23258
# [157]	validation_0-rmse:71734.99175	validation_1-rmse:67892.30926
# [158]	validation_0-rmse:71724.85610	validation_1-rmse:67890.15902
# [159]	validation_0-rmse:71713.57401	validation_1-rmse:67887.42939
# [160]	validation_0-rmse:71707.27717	validation_1-rmse:67886.16112
# [161]	validation_0-rmse:71702.93729	validation_1-rmse:67885.56786
# [162]	validation_0-rmse:71694.05453	validation_1-rmse:67882.93812
# [163]	validation_0-rmse:71680.70233	validation_1-rmse:67880.61096
# [164]	validation_0-rmse:71672.36163	validation_1-rmse:67880.14481
# [165]	validation_0-rmse:71656.79372	validation_1-rmse:67877.24515
# [166]	validation_0-rmse:71653.52440	validation_1-rmse:67876.33229
# [167]	validation_0-rmse:71643.77513	validation_1-rmse:67876.51708
# [168]	validation_0-rmse:71629.94974	validation_1-rmse:67877.93541
# [169]	validation_0-rmse:71611.00447	validation_1-rmse:67879.79525
# [170]	validation_0-rmse:71605.76282	validation_1-rmse:67880.02187
# [171]	validation_0-rmse:71593.95722	validation_1-rmse:67878.77121
# [172]	validation_0-rmse:71585.31536	validation_1-rmse:67879.21352
# [173]	validation_0-rmse:71569.26478	validation_1-rmse:67880.16082
# [174]	validation_0-rmse:71564.98273	validation_1-rmse:67879.05985
# [175]	validation_0-rmse:71561.58511	validation_1-rmse:67879.85412
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.45, device='cuda', early_stopping_rounds=10,
#              enable_categorical=True, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.025, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=18, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=700, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(15,5))
result_light  = lgb_reg.evals_result_
epochs_light = len(result_light['training']['rmse'])
x_axis_light = range(0, epochs_light)
ax[0].plot(x_axis_light, result_light['training']['rmse'], label='train',c='r')
ax[0].plot(x_axis_light, result_light['valid_1']['rmse'], label='test',c='b')
ax[0].legend()
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('RMSE')
ax[0].set_title('LIGHT GBM')
result_xgb= xgb_model.evals_result()
epochs_xgb = len(result_xgb['validation_0']['rmse'])
x_axis_xgb = range(0, epochs_xgb)
ax[1].plot(x_axis_xgb, result_xgb['validation_0']['rmse'], label='train',c='r')
ax[1].plot(x_axis_xgb, result_xgb['validation_1']['rmse'], label='test',c='b')
ax[1].legend()
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('RMSE')
ax[1].set_title('XGB')
plt.show()
print('Best itertaion for Light GBM is ',lgb_reg.best_iteration_)
print('Best itertaion for XGB is ',xgb_model.best_iteration)
# Out:
# Best itertaion for Light GBM is  294
# Best itertaion for XGB is  166

# %%
y_pred_xgb=xgb_model.predict(x_test)
y_pred_light= lgb_reg.predict(x_test)
y_pred_vot = np.mean([y_pred_xgb,y_pred_light],axis=0)
print('XGB -->',mean_squared_error(y_test,y_pred_xgb,squared=False) )
print('Light -->',mean_squared_error(y_test,y_pred_light,squared=False) )
print('Voting -->',mean_squared_error(y_test,y_pred_vot,squared=False) )
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [11:53:55] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# XGB --> 67876.33278006414
# Light --> 67872.63440073586
# Voting --> 67808.09248092814

# %%
dic =  {
    'XGB':y_pred_xgb,
    'Light':y_pred_light,
    'Voting':y_pred_vot
}
tt = pd.DataFrame(dic)
tt.head()
# Out:
#         XGB     Light    Voting
# 0 53305.516 45128.969 49217.242
# 1 34622.004 31631.548 33126.776
# 2 32107.832 34541.567 33324.700
# 3 22871.346 24874.428 23872.887
# 4 34659.125 34482.825 34570.975

# %%
y_p1= xgb_model.predict(df_test)
y_p2 = lgb_reg.predict(df_test)
y_pred_vot = np.mean([y_p1,y_p2],axis=0)

# %%
submession = pd.DataFrame({
    'id':ts['id'].values,
    'price':y_pred_vot

})

# %%
submession.head()
# Out:
#        id     price
# 0  188533 18596.048
# 1  188534 73607.603
# 2  188535 61932.545
# 3  188536 31343.326
# 4  188537 30837.639

# %%
submession.to_csv('submession.csv', index=False)
