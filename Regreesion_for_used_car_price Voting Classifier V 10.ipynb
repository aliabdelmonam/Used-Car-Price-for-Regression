# %% [markdown]
# <a href="https://www.kaggle.com/code/aliabdelmenam/used-car-price-regreesion?scriptVersionId=195852499" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/aliabdelmonam/Used-Car-Price-for-Regression/blob/main/Regreesion_for_used_car_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from sklearn.preprocessing import StandardScaler,OrdinalEncoder,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from datetime import date
from sklearn.ensemble import IsolationForest,VotingRegressor

# %%
tr= pd.read_csv('/kaggle/input/playground-series-s4e9/train.csv')
ts= pd.read_csv('/kaggle/input/playground-series-s4e9/test.csv')
# y_zz = pd.read_csv('/kaggle/input/playground-series-s4e9/sample_submission.csv')

# %%
# y_zz.drop('id',axis=1,inplace=True)

# %%
tr.shape
# Out:
# (188533, 13)

# %%
tr.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %%
df_train = copy.deepcopy(tr)
df_test = copy.deepcopy(ts)

# %%
pd.set_option('display.max_columns', None)

# %%
# print(df_train['engine'].iloc[:150].to_string())

# %%
# for col in df_train.select_dtypes(include='object'):
#     print(col)
#     print(df_train[col].nunique())
#     print(df_train[col].unique())
#     print('-----------------------------------------')

# %%
# for col in df_train.select_dtypes(include='object'):
#     print(df_train[col].value_counts().sort_values(ascending=False).head(10))
#     print('----------------------------------------------------')

# %%
df_train.isna().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %% [markdown]
# # **VIS**

# %%
# cols_dict = {
#       'brand':'brand',
#       'model_year':'model_year',
#       "accident": "accident",
#       "exterior color" : "ext_col",
#       "interior color" : "int_col",
# }
# target='price'

# %%
# props1 = "background-color: white; color: maroon; font-weight: bold; "
# props2 = "background-color: white; color: blue; font-weight: bold; "

# %%
# for label, col in cols_dict.items():
#   t=tr[[col,target]].groupby(col).agg({target: ["max", "min", "mean", "median", "size"]})
#   display(t.sort_values(by = col, ascending = True).\
#                 transpose().\
#                 style.format(formatter = '{:,.0f}').\
#                 set_caption(f"\nPrice details by {label}\n").\
#                 highlight_max(axis=1, props = props1).\
#                 highlight_min(axis=1, props = props2)
#                  )
#   print("\n\n\n")

# %%
# pd.options.display.float_format = '{:.5f}'.format

# %%
import re

# %% [markdown]
# # **Feature Extraction**

# %%
df_train['Horse_power']= df_train['engine'].str.extract(r'(\d+)\.?\d*HP').astype(float)
df_train['Engine_Displacement']= df_train['engine'].str.extract(r'(\d+\.?\d*)L').astype(float)
df_train['Cylinder_Count']= df_train['engine'].str.extract(r'(\d+) Cylinder ').astype(float)

df_test['Horse_power']= df_test['engine'].str.extract(r'(\d+)\.?\d*HP').astype(float)
df_test['Engine_Displacement']= df_test['engine'].str.extract(r'(\d+\.?\d*)L').astype(float)
df_test['Cylinder_Count']= df_test['engine'].str.extract(r'(\d+) Cylinder ').astype(float)

cylinder_config={'V','Flat','Straight'}
Turbocharger = {'Turbo','Twin Turbo'}
engine_type ={'Gasoline','Electric','Hybrid'}
FUEL_SYSTEMS = {'MPFI', 'GDI', 'PDI', 'TFSI','DOHC', 'SOHC'}

# %%
def zoo(word,cylinder_config):
  for i in cylinder_config:
    if i in word:
      return i
  return 'Nan'

# %%
df_train['cylinder_config']=df_train['engine'].apply(zoo,args=(cylinder_config,))
df_train['Turbocharger']=df_train['engine'].apply(zoo,args=(Turbocharger,))
df_train['engine_type']=df_train['engine'].apply(zoo,args=(engine_type,))
df_train['FUEL_SYSTEMS']=df_train['engine'].apply(zoo,args=(FUEL_SYSTEMS,))

df_test['cylinder_config']=df_test['engine'].apply(zoo,args=(cylinder_config,))
df_test['Turbocharger']=df_test['engine'].apply(zoo,args=(Turbocharger,))
df_test['engine_type']=df_test['engine'].apply(zoo,args=(engine_type,))
df_test['FUEL_SYSTEMS']=df_test['engine'].apply(zoo,args=(FUEL_SYSTEMS,))

# %%
df_train
# Out:
#             id          brand                     model  model_year  milage  \
# 0            0           MINI             Cooper S Base        2007  213000
# 1            1        Lincoln                     LS V8        2002  143250
# 2            2      Chevrolet         Silverado 2500 LT        2002  136731
# 3            3        Genesis          G90 5.0 Ultimate        2017   19500
# 4            4  Mercedes-Benz               Metris Base        2021    7388
# ...        ...            ...                       ...         ...     ...
# 188528  188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188531  188531           Audi          S5 3.0T Prestige        2022   13895
# 188532  188532        Porsche                Macan Base        2016   59500
#
#             fuel_type                                             engine  \
# 0            Gasoline       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1            Gasoline       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2       E85 Flex Fuel  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3            Gasoline       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4            Gasoline       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...               ...                                                ...
# 188528       Gasoline       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188529       Gasoline      385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188530       Gasoline       469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188531       Gasoline                                               3.0L
# 188532       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                           transmission                    ext_col int_col  \
# 0                                  A/T                     Yellow    Gray
# 1                                  A/T                     Silver   Beige
# 2                                  A/T                       Blue    Gray
# 3       Transmission w/Dual Shift Mode                      Black   Black
# 4                          7-Speed A/T                      Black   Beige
# ...                                ...                        ...     ...
# 188528  Transmission w/Dual Shift Mode                      White   Beige
# 188529                     8-Speed A/T                      White   Black
# 188530                     7-Speed A/T                      White   Black
# 188531               1-Speed Automatic  Daytona Gray Pearl Effect   Black
# 188532  Transmission w/Dual Shift Mode                      White   Black
#
#                                       accident clean_title  price  \
# 0                                None reported         Yes   4200
# 1       At least 1 accident or damage reported         Yes   4999
# 2                                None reported         Yes  13900
# 3                                None reported         Yes  45000
# 4                                None reported         Yes  97500
# ...                                        ...         ...    ...
# 188528                           None reported         Yes  27500
# 188529  At least 1 accident or damage reported         Yes  30000
# 188530                           None reported         Yes  86900
# 188531                           None reported         NaN  84900
# 188532                           None reported         Yes  28995
#
#         Horse_power  Engine_Displacement  Cylinder_Count cylinder_config  \
# 0             172.0                  1.6             4.0             Nan
# 1             252.0                  3.9             8.0             Nan
# 2             320.0                  5.3             8.0             Nan
# 3             420.0                  5.0             8.0             Nan
# 4             208.0                  2.0             4.0             Nan
# ...             ...                  ...             ...             ...
# 188528        420.0                  6.2             8.0             Nan
# 188529        385.0                  3.0             6.0               V
# 188530        469.0                  4.0             8.0             Nan
# 188531          NaN                  3.0             NaN             Nan
# 188532        252.0                  2.0             4.0             Nan
#
#        Turbocharger engine_type FUEL_SYSTEMS
# 0               Nan    Gasoline          Nan
# 1               Nan    Gasoline          Nan
# 2               Nan         Nan          Nan
# 3               Nan    Gasoline          Nan
# 4               Nan    Gasoline          Nan
# ...             ...         ...          ...
# 188528          Nan    Gasoline          Nan
# 188529          Nan    Gasoline          Nan
# 188530          Nan    Gasoline          Nan
# 188531          Nan         Nan          Nan
# 188532          Nan    Gasoline          Nan
#
# [188533 rows x 20 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   188533 non-null  int64
#  1   brand                188533 non-null  object
#  2   model                188533 non-null  object
#  3   model_year           188533 non-null  int64
#  4   milage               188533 non-null  int64
#  5   fuel_type            183450 non-null  object
#  6   engine               188533 non-null  object
#  7   transmission         188533 non-null  object
#  8   ext_col              188533 non-null  object
#  9   int_col              188533 non-null  object
#  10  accident             186081 non-null  object
#  11  clean_title          167114 non-null  object
#  12  price                188533 non-null  int64
#  13  Horse_power          155274 non-null  float64
#  14  Engine_Displacement  174319 non-null  float64
#  15  Cylinder_Count       150625 non-null  float64
#  16  cylinder_config      188533 non-null  object
#  17  Turbocharger         188533 non-null  object
#  18  engine_type          188533 non-null  object
#  19  FUEL_SYSTEMS         188533 non-null  object
# dtypes: float64(3), int64(4), object(13)
# memory usage: 28.8+ MB

# %%
df_train['transmission'].unique()
# Out:
# array(['A/T', 'Transmission w/Dual Shift Mode', '7-Speed A/T',
#        '8-Speed A/T', '10-Speed Automatic', '1-Speed A/T', '6-Speed A/T',
#        '10-Speed A/T', '9-Speed A/T', '8-Speed Automatic',
#        '9-Speed Automatic', '5-Speed A/T', 'Automatic',
#        '7-Speed Automatic with Auto-Shift', 'CVT Transmission',
#        '5-Speed M/T', 'M/T', '6-Speed M/T', '6-Speed Automatic',
#        '4-Speed Automatic', '7-Speed M/T', '2-Speed A/T',
#        '1-Speed Automatic', 'Automatic CVT', '4-Speed A/T',
#        '6-Speed Manual', 'Transmission Overdrive Switch',
#        '8-Speed Automatic with Auto-Shift', '7-Speed Manual',
#        '7-Speed Automatic', '9-Speed Automatic with Auto-Shift',
#        '6-Speed Automatic with Auto-Shift',
#        '6-Speed Electronically Controlled Automatic with O', 'F', 'CVT-F',
#        '8-Speed Manual', 'Manual', '–', '2', '6 Speed At/Mt',
#        '5-Speed Automatic', '2-Speed Automatic', '8-SPEED A/T', '7-Speed',
#        'Variable', 'Single-Speed Fixed Gear', '8-SPEED AT',
#        '10-Speed Automatic with Overdrive', '7-Speed DCT Automatic',
#        'SCHEDULED FOR OR IN PRODUCTION', '6-Speed', '6 Speed Mt'],
#       dtype=object)

# %%
# print(df_train['transmission'].iloc[:150].to_string())

# %%
# df_train['transmission'].value_counts()

# %%
# def extract_transmition (word):
#   def get_number ():
#     n=re.findall('\d+',word)
#     return n[0] if n else ''
#   if any(i in word for i in ['AT','A/T','At/Mt','Automatic'] ):
#     return ('AT'+str(get_number()))
#   elif any(i in word for i in ['CVT'] ):
#      return ('CVT'+str(get_number()))
#   elif any(i in word for i in ['Manual','M/T'] ):
#     return ('MT'+str(get_number()))
#   else :
#     return 'other'
def extract_transmition (word):
  def get_number ():
    n=re.findall('\d+',word)
    return n[0] if n else ''
  if any(i in word for i in ['AT','A/T','At/Mt','Automatic'] ):
    return ('AT')
  elif any(i in word for i in ['CVT'] ):
     return ('CVT')
  elif any(i in word for i in ['Manual','M/T'] ):
    return ('MT')
  else :
    return 'other'

# %%
df_train['new_transmission']=df_train['transmission'].apply(extract_transmition)
df_test['new_transmission']=df_test['transmission'].apply(extract_transmition)

# %%
df_train[['new_transmission','transmission']].head(20)
# Out:
#    new_transmission                    transmission
# 0                AT                             A/T
# 1                AT                             A/T
# 2                AT                             A/T
# 3             other  Transmission w/Dual Shift Mode
# 4                AT                     7-Speed A/T
# 5                AT                             A/T
# 6                AT                     8-Speed A/T
# 7                AT                             A/T
# 8                AT              10-Speed Automatic
# 9             other  Transmission w/Dual Shift Mode
# 10               AT                             A/T
# 11               AT                     1-Speed A/T
# 12               AT                     6-Speed A/T
# 13               AT                             A/T
# 14               AT                             A/T
# 15               AT                     7-Speed A/T
# 16               AT                    10-Speed A/T
# 17               AT                     8-Speed A/T
# 18               AT                     7-Speed A/T
# 19               AT                     9-Speed A/T

# %%
year = date.today().year
df_train['model_age'] = year - df_train['model_year']
df_test['model_age'] = year - df_test['model_year']

# %%
df_train.drop(['engine','transmission','model'],axis=1,inplace=True)
df_test.drop(['engine','transmission','model'],axis=1,inplace=True)
df_train.drop('id',axis=1,inplace=True)
df_test.drop('id',axis=1,inplace=True)
df_train.drop(['model_year'],axis=1,inplace=True)
df_test.drop(['model_year'],axis=1,inplace=True)

# %%
df_test.head()
# Out:
#   brand  milage fuel_type          ext_col int_col       accident clean_title  \
# 0  Land   98000  Gasoline            White   Beige  None reported         Yes
# 1  Land    9142    Hybrid           Silver   Black  None reported         Yes
# 2  Ford   28121  Gasoline            White   Ebony  None reported         NaN
# 3  Audi   61258  Gasoline  Silician Yellow   Black  None reported         NaN
# 4  Audi   59000  Gasoline             Gray   Black  None reported         Yes
#
#    Horse_power  Engine_Displacement  Cylinder_Count cylinder_config  \
# 0        240.0                  2.0             4.0             Nan
# 1        395.0                  3.0             6.0        Straight
# 2          NaN                  3.5             NaN               V
# 3          NaN                  NaN             NaN             Nan
# 4        252.0                  2.0             4.0             Nan
#
#   Turbocharger engine_type FUEL_SYSTEMS new_transmission  model_age
# 0          Nan    Gasoline          Nan               AT          9
# 1          Nan    Gasoline          Nan               AT          4
# 2        Turbo         Nan         DOHC               AT          2
# 3          Nan         Nan         TFSI               AT          8
# 4          Nan    Gasoline          Nan               AT          6

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   brand                188533 non-null  object
#  1   milage               188533 non-null  int64
#  2   fuel_type            183450 non-null  object
#  3   ext_col              188533 non-null  object
#  4   int_col              188533 non-null  object
#  5   accident             186081 non-null  object
#  6   clean_title          167114 non-null  object
#  7   price                188533 non-null  int64
#  8   Horse_power          155274 non-null  float64
#  9   Engine_Displacement  174319 non-null  float64
#  10  Cylinder_Count       150625 non-null  float64
#  11  cylinder_config      188533 non-null  object
#  12  Turbocharger         188533 non-null  object
#  13  engine_type          188533 non-null  object
#  14  FUEL_SYSTEMS         188533 non-null  object
#  15  new_transmission     188533 non-null  object
#  16  model_age            188533 non-null  int64
# dtypes: float64(3), int64(3), object(11)
# memory usage: 24.5+ MB

# %%
df_train.isna().sum()
# Out:
# brand                      0
# milage                     0
# fuel_type               5083
# ext_col                    0
# int_col                    0
# accident                2452
# clean_title            21419
# price                      0
# Horse_power            33259
# Engine_Displacement    14214
# Cylinder_Count         37908
# cylinder_config            0
# Turbocharger               0
# engine_type                0
# FUEL_SYSTEMS               0
# new_transmission           0
# model_age                  0
# dtype: int64

# %%
df_train.head()
# Out:
#            brand  milage      fuel_type ext_col int_col  \
# 0           MINI  213000       Gasoline  Yellow    Gray
# 1        Lincoln  143250       Gasoline  Silver   Beige
# 2      Chevrolet  136731  E85 Flex Fuel    Blue    Gray
# 3        Genesis   19500       Gasoline   Black   Black
# 4  Mercedes-Benz    7388       Gasoline   Black   Beige
#
#                                  accident clean_title  price  Horse_power  \
# 0                           None reported         Yes   4200        172.0
# 1  At least 1 accident or damage reported         Yes   4999        252.0
# 2                           None reported         Yes  13900        320.0
# 3                           None reported         Yes  45000        420.0
# 4                           None reported         Yes  97500        208.0
#
#    Engine_Displacement  Cylinder_Count cylinder_config Turbocharger  \
# 0                  1.6             4.0             Nan          Nan
# 1                  3.9             8.0             Nan          Nan
# 2                  5.3             8.0             Nan          Nan
# 3                  5.0             8.0             Nan          Nan
# 4                  2.0             4.0             Nan          Nan
#
#   engine_type FUEL_SYSTEMS new_transmission  model_age
# 0    Gasoline          Nan               AT         17
# 1    Gasoline          Nan               AT         22
# 2         Nan          Nan               AT         22
# 3    Gasoline          Nan            other          7
# 4    Gasoline          Nan               AT          3

# %%
y=df_train['price']
df_train=df_train.drop('price',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(df_train,y,test_size=.2,random_state=42)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   brand                188533 non-null  object
#  1   milage               188533 non-null  int64
#  2   fuel_type            183450 non-null  object
#  3   ext_col              188533 non-null  object
#  4   int_col              188533 non-null  object
#  5   accident             186081 non-null  object
#  6   clean_title          167114 non-null  object
#  7   Horse_power          155274 non-null  float64
#  8   Engine_Displacement  174319 non-null  float64
#  9   Cylinder_Count       150625 non-null  float64
#  10  cylinder_config      188533 non-null  object
#  11  Turbocharger         188533 non-null  object
#  12  engine_type          188533 non-null  object
#  13  FUEL_SYSTEMS         188533 non-null  object
#  14  new_transmission     188533 non-null  object
#  15  model_age            188533 non-null  int64
# dtypes: float64(3), int64(2), object(11)
# memory usage: 23.0+ MB

# %% [markdown]
# # **PipeLine**

# %%
num_col = df_train.select_dtypes(include='number').columns
cat_col = df_train.select_dtypes(include='object').columns

# %%
num_imputer= SimpleImputer(strategy='mean')
cat_imputer= SimpleImputer(strategy='most_frequent')
encoder = OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value=-1)
scaler = StandardScaler()
#############################################3
for col in num_col:
  x_train[col] = num_imputer.fit_transform(x_train[[col]])
  x_test[col] = num_imputer.transform(x_test[[col]])

  df_test[col] = num_imputer.transform(df_test[[col]])

  x_train[col] = scaler.fit_transform(x_train[[col]])
  x_test[col] = scaler.transform(x_test[[col]])
  df_test[col] = scaler.transform(df_test[[col]])
##############################################
for col in cat_col:
  x_train[[col]] = cat_imputer.fit_transform(x_train[col].values.reshape(-1,1))
  x_test[[col]] = cat_imputer.transform(x_test[col].values.reshape(-1,1))

  df_test[[col]] = cat_imputer.transform(df_test[col].values.reshape(-1,1))

  x_train[col] = encoder.fit_transform(x_train[[col]])
  x_test[col] = encoder.transform(x_test[[col]])

  df_test[col] = encoder.transform(df_test[[col]])

# %%
df_train.head()
# Out:
#            brand  milage      fuel_type ext_col int_col  \
# 0           MINI  213000       Gasoline  Yellow    Gray
# 1        Lincoln  143250       Gasoline  Silver   Beige
# 2      Chevrolet  136731  E85 Flex Fuel    Blue    Gray
# 3        Genesis   19500       Gasoline   Black   Black
# 4  Mercedes-Benz    7388       Gasoline   Black   Beige
#
#                                  accident clean_title  Horse_power  \
# 0                           None reported         Yes        172.0
# 1  At least 1 accident or damage reported         Yes        252.0
# 2                           None reported         Yes        320.0
# 3                           None reported         Yes        420.0
# 4                           None reported         Yes        208.0
#
#    Engine_Displacement  Cylinder_Count cylinder_config Turbocharger  \
# 0                  1.6             4.0             Nan          Nan
# 1                  3.9             8.0             Nan          Nan
# 2                  5.3             8.0             Nan          Nan
# 3                  5.0             8.0             Nan          Nan
# 4                  2.0             4.0             Nan          Nan
#
#   engine_type FUEL_SYSTEMS new_transmission  model_age
# 0    Gasoline          Nan               AT         17
# 1    Gasoline          Nan               AT         22
# 2         Nan          Nan               AT         22
# 3    Gasoline          Nan            other          7
# 4    Gasoline          Nan               AT          3

# %%
pd.options.display.float_format = '{:.3f}'.format

# %%
zob=pd.DataFrame(x_train,columns=df_train.columns)
zob
# Out:
#         brand  milage  fuel_type  ext_col  int_col  accident  clean_title  \
# 184031 36.000  -0.082      1.000  128.000   14.000     0.000        0.000
# 173831 39.000   2.396      2.000  263.000   71.000     0.000        0.000
# 183819 14.000   0.527      2.000  128.000   71.000     0.000        0.000
# 85525  19.000  -1.211      2.000   29.000   14.000     1.000        0.000
# 41872  11.000  -1.221      2.000  234.000   14.000     1.000        0.000
# ...       ...     ...        ...      ...      ...       ...          ...
# 119879  9.000   0.469      2.000  234.000   10.000     0.000        0.000
# 103694  4.000  -0.170      2.000   29.000   14.000     1.000        0.000
# 131932 43.000  -0.688      2.000   29.000   14.000     1.000        0.000
# 146867 36.000   2.416      2.000   29.000   14.000     1.000        0.000
# 121958 32.000  -1.201      2.000  177.000   14.000     1.000        0.000
#
#         Horse_power  Engine_Displacement  Cylinder_Count  cylinder_config  \
# 184031       -1.297               -1.386          -1.706            1.000
# 173831       -1.000                0.149          -0.268            3.000
# 183819       -0.175               -0.849          -0.268            3.000
# 85525        -0.645               -1.386          -1.706            1.000
# 41872         3.584                1.838           1.169            1.000
# ...             ...                  ...             ...              ...
# 119879        0.065                1.454           1.169            1.000
# 103694       -0.223               -0.619          -0.268            2.000
# 131932        0.736               -0.619          -0.268            0.000
# 146867       -0.722               -0.235          -0.268            3.000
# 121958       -0.000               -0.619          -0.000            3.000
#
#         Turbocharger  engine_type  FUEL_SYSTEMS  new_transmission  model_age
# 184031         0.000        3.000         3.000             3.000     -0.208
# 173831         0.000        1.000         3.000             0.000      2.268
# 183819         0.000        1.000         3.000             0.000     -0.738
# 85525          0.000        1.000         3.000             2.000     -1.268
# 41872          0.000        1.000         3.000             0.000     -1.268
# ...              ...          ...           ...               ...        ...
# 119879         0.000        1.000         3.000             2.000      1.560
# 103694         0.000        1.000         3.000             0.000     -0.561
# 131932         0.000        1.000         3.000             0.000     -0.915
# 146867         0.000        1.000         3.000             0.000      0.853
# 121958         1.000        3.000         0.000             0.000     -1.268
#
# [150826 rows x 16 columns]

# %%
isolation_forest = IsolationForest(contamination=0.024, random_state=42)
x_train_labels = isolation_forest.fit_predict(x_train) # 1 indicate normal, -1--> outlier (anomaly)
normal_bool = x_train_labels != -1 
x_train=x_train[normal_bool]
y_train=y_train[normal_bool]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(

# %%
# !pip install dython
from dython.nominal import associations
# Out:
# Collecting dython
#   Downloading dython-0.7.7-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from dython) (1.26.4)
# Requirement already satisfied: pandas>=1.4.2 in /opt/conda/lib/python3.10/site-packages (from dython) (2.2.2)
# Requirement already satisfied: seaborn>=0.12.0 in /opt/conda/lib/python3.10/site-packages (from dython) (0.12.2)
# Requirement already satisfied: scipy>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from dython) (1.14.0)
# Requirement already satisfied: matplotlib>=3.6.0 in /opt/conda/lib/python3.10/site-packages (from dython) (3.7.5)
# Requirement already satisfied: scikit-learn>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from dython) (1.2.2)
# Requirement already satisfied: psutil>=5.9.1 in /opt/conda/lib/python3.10/site-packages (from dython) (5.9.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from dython) (70.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.6.0->dython) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->dython) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->dython) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->dython) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->dython) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->dython) (1.16.0)
# Downloading dython-0.7.7-py3-none-any.whl (26 kB)
# Installing collected packages: dython
# Successfully installed dython-0.7.7

# %%
temp  = x_train.merge(y_train,left_index=True,right_index=True)
plt.figure(figsize=(15,10))
df_co=temp.corr()
mask = np.triu(np.ones_like(temp.corr())) 
sns.heatmap(df_co,annot=True,cmap='Blues',fmt='.3f',mask=mask)
plt.show()
# fig, ax = plt.subplots(figsize=(15, 10))
# correlations = associations(tr,ax=ax,cmap='Blues')

# %%
from scipy.stats import f_oneway
import scipy.stats as stats
# Example: Perform ANOVA test
brands = tr['brand']
prices = tr['price']
f_value, p_value = stats.f_oneway(*[prices[brands == brand] for brand in brands.unique()])
print(f"F-Value: {f_value}, P-Value: {p_value:.10f}")
# Out:
# F-Value: 160.90002788108941, P-Value: 0.0000000000

# %%
# x_train.drop('brand',axis=1,inplace=True)
# x_test.drop('brand',axis=1,inplace=True)
# df_test.drop('brand',axis=1,inplace=True)

# %%
(1-len(x_train)/len(x_train_labels))*100
# Out:
# 2.4001166907562377

# %%
import xgboost as xgb
from lightgbm import LGBMRegressor
import lightgbm as lgb

# %%
xgb_model=xgb.XGBRegressor(tree_method ="hist",
                          device               = "cuda" ,
                          objective             = "reg:squarederror",
                          random_state          = 42,
                          colsample_bytree      = 0.45,
                          learning_rate       = 0.025,
                          max_depth          = 7,
                          n_estimators          = 700,
                          reg_alpha          = 0.001,
                        reg_lambda            = 0.001,
                          min_child_weight      = 18,
                          enable_categorical    = True,
                        eval_metric='rmse'  ,
                           early_stopping_rounds=10,
                           verbose = 1
)
lgb_params= {
        'n_epochs': 700,
        'learning_rate': 0.01,
        'colsample_bytree': 0.55,
        'bagging_fraction': 0.8,
        'num_leaves': 3072,
        'min_child_samples': 12,
        'reg_lambda': 64, # not 128
        'max_bin': 255,
        'max_depth': 10,
        'reg_alpha': 0,
        'verbose':-1
}

# %%
lgb_reg = LGBMRegressor(**lgb_params,loss_function='RMSE',verbosity=-1)
early_stopping_light = lgb.early_stopping(stopping_rounds=10)
eval_Set = [(x_train,y_train),(x_test,y_test)]
lgb_reg.fit(x_train,y_train,eval_set =eval_Set,callbacks=[early_stopping_light],eval_metric='rmse')
xgb_model.fit(x_train,y_train,eval_set=eval_Set)
# Out:
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [100]	training's rmse: 74316.6	training's l2: 5.52296e+09	valid_1's rmse: 69613.3	valid_1's l2: 4.84601e+09
# [0]	validation_0-rmse:79161.72778	validation_1-rmse:74472.85438
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:14:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [1]	validation_0-rmse:78893.22558	validation_1-rmse:74198.36112
# [2]	validation_0-rmse:78652.29146	validation_1-rmse:73951.02413
# [3]	validation_0-rmse:78444.44410	validation_1-rmse:73730.42737
# [4]	validation_0-rmse:78273.31818	validation_1-rmse:73547.27523
# [5]	validation_0-rmse:78063.30752	validation_1-rmse:73331.65684
# [6]	validation_0-rmse:77880.51126	validation_1-rmse:73140.25041
# [7]	validation_0-rmse:77720.11938	validation_1-rmse:72980.54557
# [8]	validation_0-rmse:77521.31823	validation_1-rmse:72770.72686
# [9]	validation_0-rmse:77331.90063	validation_1-rmse:72579.53054
# [10]	validation_0-rmse:77220.24037	validation_1-rmse:72466.85240
# [11]	validation_0-rmse:77064.48451	validation_1-rmse:72306.17206
# [12]	validation_0-rmse:77002.29055	validation_1-rmse:72243.89384
# [13]	validation_0-rmse:76829.95962	validation_1-rmse:72065.79294
# [14]	validation_0-rmse:76703.15349	validation_1-rmse:71939.22667
# [15]	validation_0-rmse:76570.34018	validation_1-rmse:71802.47607
# [16]	validation_0-rmse:76431.60924	validation_1-rmse:71664.18047
# [17]	validation_0-rmse:76295.18472	validation_1-rmse:71536.37975
# [18]	validation_0-rmse:76181.21149	validation_1-rmse:71410.99926
# [19]	validation_0-rmse:76050.66310	validation_1-rmse:71286.75285
# [20]	validation_0-rmse:75941.70201	validation_1-rmse:71178.54689
# [21]	validation_0-rmse:75868.25677	validation_1-rmse:71105.05490
# [22]	validation_0-rmse:75814.07608	validation_1-rmse:71046.70134
# [23]	validation_0-rmse:75688.78435	validation_1-rmse:70928.82999
# [24]	validation_0-rmse:75579.69011	validation_1-rmse:70819.34687
# [25]	validation_0-rmse:75486.01345	validation_1-rmse:70724.60523
# [26]	validation_0-rmse:75392.60747	validation_1-rmse:70634.86550
# [27]	validation_0-rmse:75288.29430	validation_1-rmse:70546.90558
# [28]	validation_0-rmse:75197.19790	validation_1-rmse:70454.69339
# [29]	validation_0-rmse:75090.24065	validation_1-rmse:70346.78686
# [30]	validation_0-rmse:75019.77421	validation_1-rmse:70280.57184
# [31]	validation_0-rmse:74954.27510	validation_1-rmse:70215.86255
# [32]	validation_0-rmse:74854.86900	validation_1-rmse:70124.55370
# [33]	validation_0-rmse:74807.65441	validation_1-rmse:70074.91125
# [34]	validation_0-rmse:74761.35833	validation_1-rmse:70029.50596
# [35]	validation_0-rmse:74674.15331	validation_1-rmse:69950.07519
# [36]	validation_0-rmse:74624.72696	validation_1-rmse:69900.14508
# [37]	validation_0-rmse:74577.39069	validation_1-rmse:69847.73417
# [38]	validation_0-rmse:74509.99369	validation_1-rmse:69780.41778
# [39]	validation_0-rmse:74457.71345	validation_1-rmse:69727.48457
# [40]	validation_0-rmse:74392.81829	validation_1-rmse:69669.16390
# [41]	validation_0-rmse:74342.76940	validation_1-rmse:69626.46493
# [42]	validation_0-rmse:74308.61129	validation_1-rmse:69588.79577
# [43]	validation_0-rmse:74276.82452	validation_1-rmse:69552.50904
# [44]	validation_0-rmse:74256.12370	validation_1-rmse:69532.14336
# [45]	validation_0-rmse:74202.99971	validation_1-rmse:69480.60519
# [46]	validation_0-rmse:74135.79759	validation_1-rmse:69413.46907
# [47]	validation_0-rmse:74105.13540	validation_1-rmse:69384.83243
# [48]	validation_0-rmse:74073.49189	validation_1-rmse:69355.98566
# [49]	validation_0-rmse:74029.74537	validation_1-rmse:69322.28033
# [50]	validation_0-rmse:73994.75311	validation_1-rmse:69282.83322
# [51]	validation_0-rmse:73939.68716	validation_1-rmse:69233.75870
# [52]	validation_0-rmse:73881.98416	validation_1-rmse:69179.89706
# [53]	validation_0-rmse:73844.14821	validation_1-rmse:69151.96751
# [54]	validation_0-rmse:73797.89130	validation_1-rmse:69113.94774
# [55]	validation_0-rmse:73740.76006	validation_1-rmse:69078.74529
# [56]	validation_0-rmse:73704.71224	validation_1-rmse:69039.91856
# [57]	validation_0-rmse:73660.77575	validation_1-rmse:69000.33370
# [58]	validation_0-rmse:73633.59283	validation_1-rmse:68980.32014
# [59]	validation_0-rmse:73592.30438	validation_1-rmse:68945.13753
# [60]	validation_0-rmse:73550.92090	validation_1-rmse:68912.77947
# [61]	validation_0-rmse:73523.99893	validation_1-rmse:68892.91867
# [62]	validation_0-rmse:73488.84737	validation_1-rmse:68857.13933
# [63]	validation_0-rmse:73454.49353	validation_1-rmse:68825.97891
# [64]	validation_0-rmse:73426.67732	validation_1-rmse:68800.96759
# [65]	validation_0-rmse:73392.94943	validation_1-rmse:68772.83544
# [66]	validation_0-rmse:73375.06362	validation_1-rmse:68759.78701
# [67]	validation_0-rmse:73354.05210	validation_1-rmse:68746.46043
# [68]	validation_0-rmse:73332.62101	validation_1-rmse:68728.61373
# [69]	validation_0-rmse:73286.90880	validation_1-rmse:68698.10049
# [70]	validation_0-rmse:73255.45781	validation_1-rmse:68675.54602
# [71]	validation_0-rmse:73227.38260	validation_1-rmse:68651.59251
# [72]	validation_0-rmse:73213.90491	validation_1-rmse:68641.26186
# [73]	validation_0-rmse:73162.66663	validation_1-rmse:68606.01317
# [74]	validation_0-rmse:73113.62873	validation_1-rmse:68579.71165
# [75]	validation_0-rmse:73071.20612	validation_1-rmse:68554.17147
# [76]	validation_0-rmse:73034.27333	validation_1-rmse:68535.05749
# [77]	validation_0-rmse:73012.48375	validation_1-rmse:68520.57658
# [78]	validation_0-rmse:72971.84920	validation_1-rmse:68496.38756
# [79]	validation_0-rmse:72942.48423	validation_1-rmse:68482.03096
# [80]	validation_0-rmse:72912.60438	validation_1-rmse:68462.94127
# [81]	validation_0-rmse:72894.96012	validation_1-rmse:68446.49652
# [82]	validation_0-rmse:72871.48157	validation_1-rmse:68432.42602
# [83]	validation_0-rmse:72841.98882	validation_1-rmse:68414.19683
# [84]	validation_0-rmse:72823.86708	validation_1-rmse:68400.04683
# [85]	validation_0-rmse:72791.36159	validation_1-rmse:68383.33202
# [86]	validation_0-rmse:72755.81870	validation_1-rmse:68363.04407
# [87]	validation_0-rmse:72724.89336	validation_1-rmse:68342.26030
# [88]	validation_0-rmse:72715.73564	validation_1-rmse:68339.54709
# [89]	validation_0-rmse:72692.19300	validation_1-rmse:68328.25368
# [90]	validation_0-rmse:72653.99042	validation_1-rmse:68309.28753
# [91]	validation_0-rmse:72623.25085	validation_1-rmse:68296.03402
# [92]	validation_0-rmse:72604.55730	validation_1-rmse:68284.92667
# [93]	validation_0-rmse:72588.15128	validation_1-rmse:68276.42680
# [94]	validation_0-rmse:72576.51987	validation_1-rmse:68275.15120
# [95]	validation_0-rmse:72565.23023	validation_1-rmse:68269.52396
# [96]	validation_0-rmse:72548.00795	validation_1-rmse:68261.23078
# [97]	validation_0-rmse:72541.27431	validation_1-rmse:68258.11798
# [98]	validation_0-rmse:72530.26606	validation_1-rmse:68249.93347
# [99]	validation_0-rmse:72505.96353	validation_1-rmse:68235.35867
# [100]	validation_0-rmse:72493.54716	validation_1-rmse:68225.42307
# [101]	validation_0-rmse:72474.75064	validation_1-rmse:68214.67623
# [102]	validation_0-rmse:72448.99964	validation_1-rmse:68201.33028
# [103]	validation_0-rmse:72428.85260	validation_1-rmse:68193.58001
# [104]	validation_0-rmse:72414.40198	validation_1-rmse:68184.56057
# [105]	validation_0-rmse:72395.50898	validation_1-rmse:68174.05316
# [106]	validation_0-rmse:72369.41407	validation_1-rmse:68167.63391
# [107]	validation_0-rmse:72360.60556	validation_1-rmse:68165.02385
# [108]	validation_0-rmse:72354.14187	validation_1-rmse:68161.08246
# [109]	validation_0-rmse:72336.76367	validation_1-rmse:68150.34596
# [110]	validation_0-rmse:72307.26293	validation_1-rmse:68137.84128
# [111]	validation_0-rmse:72294.29006	validation_1-rmse:68133.03500
# [112]	validation_0-rmse:72284.28793	validation_1-rmse:68126.30302
# [113]	validation_0-rmse:72271.70061	validation_1-rmse:68121.46091
# [114]	validation_0-rmse:72258.39607	validation_1-rmse:68115.34293
# [115]	validation_0-rmse:72250.41633	validation_1-rmse:68113.93921
# [116]	validation_0-rmse:72235.62559	validation_1-rmse:68108.86697
# [117]	validation_0-rmse:72212.35198	validation_1-rmse:68103.24715
# [118]	validation_0-rmse:72194.35668	validation_1-rmse:68097.08425
# [119]	validation_0-rmse:72176.31392	validation_1-rmse:68092.18282
# [120]	validation_0-rmse:72148.19519	validation_1-rmse:68086.19981
# [121]	validation_0-rmse:72128.67204	validation_1-rmse:68080.66804
# [122]	validation_0-rmse:72113.04772	validation_1-rmse:68074.33616
# [123]	validation_0-rmse:72104.23860	validation_1-rmse:68072.22752
# [124]	validation_0-rmse:72096.70181	validation_1-rmse:68068.05330
# [125]	validation_0-rmse:72088.68075	validation_1-rmse:68067.91998
# [126]	validation_0-rmse:72079.18118	validation_1-rmse:68068.16135
# [127]	validation_0-rmse:72074.82456	validation_1-rmse:68067.83479
# [128]	validation_0-rmse:72067.19519	validation_1-rmse:68064.95556
# [129]	validation_0-rmse:72047.40407	validation_1-rmse:68065.48160
# [130]	validation_0-rmse:72039.88447	validation_1-rmse:68063.75166
# [131]	validation_0-rmse:72025.74423	validation_1-rmse:68060.07274
# [132]	validation_0-rmse:72021.25181	validation_1-rmse:68058.07990
# [133]	validation_0-rmse:72007.15073	validation_1-rmse:68053.97690
# [134]	validation_0-rmse:71998.47499	validation_1-rmse:68052.19068
# [135]	validation_0-rmse:71989.81228	validation_1-rmse:68050.55529
# [136]	validation_0-rmse:71982.15103	validation_1-rmse:68047.27615
# [137]	validation_0-rmse:71956.83403	validation_1-rmse:68042.95797
# [138]	validation_0-rmse:71949.60138	validation_1-rmse:68041.76614
# [139]	validation_0-rmse:71928.68944	validation_1-rmse:68034.39813
# [140]	validation_0-rmse:71911.36719	validation_1-rmse:68032.28060
# [141]	validation_0-rmse:71908.13889	validation_1-rmse:68031.65107
# [142]	validation_0-rmse:71897.66821	validation_1-rmse:68029.06585
# [143]	validation_0-rmse:71887.62271	validation_1-rmse:68028.34284
# [144]	validation_0-rmse:71880.79957	validation_1-rmse:68027.70344
# [145]	validation_0-rmse:71875.48913	validation_1-rmse:68027.85626
# [146]	validation_0-rmse:71870.54978	validation_1-rmse:68026.93522
# [147]	validation_0-rmse:71855.33959	validation_1-rmse:68024.98471
# [148]	validation_0-rmse:71846.00787	validation_1-rmse:68022.30027
# [149]	validation_0-rmse:71835.50076	validation_1-rmse:68020.14922
# [150]	validation_0-rmse:71820.60100	validation_1-rmse:68017.10482
# [151]	validation_0-rmse:71817.12805	validation_1-rmse:68015.46698
# [152]	validation_0-rmse:71808.06198	validation_1-rmse:68014.72381
# [153]	validation_0-rmse:71802.71603	validation_1-rmse:68014.42815
# [154]	validation_0-rmse:71796.83436	validation_1-rmse:68011.96382
# [155]	validation_0-rmse:71791.61953	validation_1-rmse:68011.01746
# [156]	validation_0-rmse:71786.63644	validation_1-rmse:68010.94623
# [157]	validation_0-rmse:71780.24075	validation_1-rmse:68012.53989
# [158]	validation_0-rmse:71778.38405	validation_1-rmse:68012.83229
# [159]	validation_0-rmse:71768.32948	validation_1-rmse:68014.27068
# [160]	validation_0-rmse:71764.59189	validation_1-rmse:68011.64842
# [161]	validation_0-rmse:71756.58561	validation_1-rmse:68008.34183
# [162]	validation_0-rmse:71747.15873	validation_1-rmse:68007.38970
# [163]	validation_0-rmse:71741.34594	validation_1-rmse:68006.68913
# [164]	validation_0-rmse:71736.97874	validation_1-rmse:68004.45441
# [165]	validation_0-rmse:71733.78788	validation_1-rmse:68004.82744
# [166]	validation_0-rmse:71725.13312	validation_1-rmse:68006.13035
# [167]	validation_0-rmse:71698.78785	validation_1-rmse:68000.62941
# [168]	validation_0-rmse:71689.71326	validation_1-rmse:67998.20653
# [169]	validation_0-rmse:71673.85101	validation_1-rmse:67997.33982
# [170]	validation_0-rmse:71669.76077	validation_1-rmse:67998.12308
# [171]	validation_0-rmse:71661.60509	validation_1-rmse:67998.39680
# [172]	validation_0-rmse:71655.56868	validation_1-rmse:67995.09344
# [173]	validation_0-rmse:71650.82855	validation_1-rmse:67993.86048
# [174]	validation_0-rmse:71645.93206	validation_1-rmse:67993.83030
# [175]	validation_0-rmse:71638.91289	validation_1-rmse:67991.56391
# [176]	validation_0-rmse:71620.10451	validation_1-rmse:67989.71903
# [177]	validation_0-rmse:71616.18634	validation_1-rmse:67991.00279
# [178]	validation_0-rmse:71611.16392	validation_1-rmse:67991.70341
# [179]	validation_0-rmse:71595.24792	validation_1-rmse:67987.73292
# [180]	validation_0-rmse:71592.25664	validation_1-rmse:67987.23892
# [181]	validation_0-rmse:71578.07550	validation_1-rmse:67979.91190
# [182]	validation_0-rmse:71555.66830	validation_1-rmse:67973.30880
# [183]	validation_0-rmse:71551.09819	validation_1-rmse:67975.13583
# [184]	validation_0-rmse:71548.59268	validation_1-rmse:67973.64570
# [185]	validation_0-rmse:71540.66270	validation_1-rmse:67970.26894
# [186]	validation_0-rmse:71527.49626	validation_1-rmse:67969.04905
# [187]	validation_0-rmse:71505.86429	validation_1-rmse:67970.64641
# [188]	validation_0-rmse:71482.73691	validation_1-rmse:67961.21101
# [189]	validation_0-rmse:71464.16258	validation_1-rmse:67957.40672
# [190]	validation_0-rmse:71447.70353	validation_1-rmse:67957.88806
# [191]	validation_0-rmse:71436.33882	validation_1-rmse:67953.65285
# [192]	validation_0-rmse:71431.24148	validation_1-rmse:67955.05106
# [193]	validation_0-rmse:71416.45575	validation_1-rmse:67953.98833
# [194]	validation_0-rmse:71412.64936	validation_1-rmse:67955.89452
# [195]	validation_0-rmse:71405.43300	validation_1-rmse:67954.71576
# [196]	validation_0-rmse:71402.33702	validation_1-rmse:67953.60178
# [197]	validation_0-rmse:71392.81044	validation_1-rmse:67955.82259
# [198]	validation_0-rmse:71383.61493	validation_1-rmse:67958.04048
# [199]	validation_0-rmse:71379.70942	validation_1-rmse:67959.67078
# [200]	validation_0-rmse:71363.40502	validation_1-rmse:67954.72710
# [201]	validation_0-rmse:71357.13628	validation_1-rmse:67953.26054
# [202]	validation_0-rmse:71349.04407	validation_1-rmse:67952.83524
# [203]	validation_0-rmse:71342.70614	validation_1-rmse:67951.36522
# [204]	validation_0-rmse:71339.28954	validation_1-rmse:67953.30591
# [205]	validation_0-rmse:71332.87197	validation_1-rmse:67951.38929
# [206]	validation_0-rmse:71328.65796	validation_1-rmse:67952.03867
# [207]	validation_0-rmse:71322.92935	validation_1-rmse:67948.91183
# [208]	validation_0-rmse:71313.87049	validation_1-rmse:67945.82475
# [209]	validation_0-rmse:71308.64800	validation_1-rmse:67947.07741
# [210]	validation_0-rmse:71304.90600	validation_1-rmse:67945.49770
# [211]	validation_0-rmse:71300.80912	validation_1-rmse:67944.83233
# [212]	validation_0-rmse:71292.84796	validation_1-rmse:67943.52697
# [213]	validation_0-rmse:71289.19310	validation_1-rmse:67943.79035
# [214]	validation_0-rmse:71281.68704	validation_1-rmse:67943.14945
# [215]	validation_0-rmse:71266.79147	validation_1-rmse:67941.08218
# [216]	validation_0-rmse:71263.29032	validation_1-rmse:67941.77459
# [217]	validation_0-rmse:71253.56870	validation_1-rmse:67940.54058
# [218]	validation_0-rmse:71247.99510	validation_1-rmse:67938.98350
# [219]	validation_0-rmse:71244.33731	validation_1-rmse:67941.36623
# [220]	validation_0-rmse:71241.23967	validation_1-rmse:67941.98588
# [221]	validation_0-rmse:71239.02344	validation_1-rmse:67941.35673
# [222]	validation_0-rmse:71229.72128	validation_1-rmse:67941.72529
# [223]	validation_0-rmse:71227.71702	validation_1-rmse:67943.27727
# [224]	validation_0-rmse:71225.20888	validation_1-rmse:67944.17454
# [225]	validation_0-rmse:71213.47741	validation_1-rmse:67944.54865
# [226]	validation_0-rmse:71207.93517	validation_1-rmse:67943.17188
# [227]	validation_0-rmse:71198.69952	validation_1-rmse:67939.79364
# [228]	validation_0-rmse:71195.99887	validation_1-rmse:67939.10069
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.45, device='cuda', early_stopping_rounds=10,
#              enable_categorical=True, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.025, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=18, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=700, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(15,5))
result_light  = lgb_reg.evals_result_
epochs_light = len(result_light['training']['rmse'])
x_axis_light = range(0, epochs_light)
ax[0].plot(x_axis_light, result_light['training']['rmse'], label='train',c='r')
ax[0].plot(x_axis_light, result_light['valid_1']['rmse'], label='test',c='b')
ax[0].legend()
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('RMSE')
ax[0].set_title('LIGHT GBM')
result_xgb= xgb_model.evals_result()
epochs_xgb = len(result_xgb['validation_0']['rmse'])
x_axis_xgb = range(0, epochs_xgb)
ax[1].plot(x_axis_xgb, result_xgb['validation_0']['rmse'], label='train',c='r')
ax[1].plot(x_axis_xgb, result_xgb['validation_1']['rmse'], label='test',c='b')
ax[1].legend()
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('RMSE')
ax[1].set_title('XGB')
plt.show()
print('Best itertaion for Light GBM is ',lgb_reg.best_iteration_)
print('Best itertaion for XGB is ',xgb_model.best_iteration)
# Out:
# Best itertaion for Light GBM is  100
# Best itertaion for XGB is  218

# %%
y_pred_xgb=xgb_model.predict(x_test)
y_pred_light= lgb_reg.predict(x_test)
print('XGB -->',mean_squared_error(y_test,y_pred_xgb,squared=False) )
print('Light -->',mean_squared_error(y_test,y_pred_light,squared=False) )
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:14:17] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# XGB --> 67938.98319994709
# Light --> 69613.26523323965

# %%
# vtr=VotingRegressor(estimators=[('xgboost',xgb_model),('lightbgm',lgb_reg)])
# vtr.fit(x_train,y_train)
# y_zp=vtr.predict(x_test)
# mean_squared_error(y_test,y_zp,squared=False)

# %%
# print(r2_score(y_test,y_pred))
# r2_score(y_test,y_pred1)

# %%
y_p1= xgb_model.predict(df_test)
y_p2 = lgb_reg.predict(df_test)
# y_p3 = vtr.predict(df_test)

# %%
# print(np.sqrt(mean_squared_error(y_zz,y_p1) ))
# print(np.sqrt(mean_squared_error(y_zz,y_p2) ))
# print(np.sqrt(mean_squared_error(y_zz,y_p3) ))

# %%
submession = pd.DataFrame({
    'id':ts['id'].values,
    'price':y_p1

})

# %%
submession.head()
# Out:
#        id     price
# 0  188533 17787.039
# 1  188534 80897.469
# 2  188535 54552.652
# 3  188536 33715.828
# 4  188537 29836.199

# %%
submession.to_csv('submession.csv', index=False)
